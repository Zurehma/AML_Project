# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/Zurehma/AML_Project/blob/zurehma/code/centralized_baseline_clean.ipynb)

# %%
# !pip install torch-optimizer

# %%
# colab test

import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.nn.functional as F
from torchvision.datasets import CIFAR10, CIFAR100
import torchvision.models as models
from torch.utils.data import DataLoader
from torch_optimizer import LARS
import math

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import time
import pickle
import numpy as np
import random

print("PyTorch version:", torch.__version__)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Seeding for reproducibility
seed = 2025
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# transforms
train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])


# load data

def load_data(dataset_name="cifar100", batch_size=128, num_workers=2):

    if dataset_name.lower() == "cifar10":
        train_dataset = CIFAR10(root='./data', train=True, download=True, transform=train_transform)
        test_dataset = CIFAR10(root='./data', train=False, download=True, transform=test_transform)
        num_classes = 10
    elif dataset_name.lower() == "cifar100":
        train_dataset = CIFAR100(root='./data', train=True, download=True, transform=train_transform)
        test_dataset = CIFAR100(root='./data', train=False, download=True, transform=test_transform)
        num_classes = 100
    else:
        raise ValueError(f"Unknown dataset: {dataset_name}")

    # data loaders
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True
    )

    return train_loader, test_loader, num_classes


# model - LeNet5 from the paper [11]
class LeNet5(nn.Module):
  def __init__(self, num_classes=10):
    super(LeNet5, self).__init__()
    # Input: 3x32x32 (CIFAR has 3 color channels)
    self.conv1 = nn.Conv2d(3, 6, kernel_size=5)  # Output: 6x28x28
    self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # Output: 6x14x14
    self.conv2 = nn.Conv2d(6, 16, kernel_size=5)  # Output: 16x10x10
    self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)  # Output: 16x5x5

    # fc layers
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, num_classes)

  def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5) # flatten
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def create_model(model_name, num_classes=10):
    if model_name.lower() == "lenet5":
        return LeNet5(num_classes=num_classes)
    else:
        raise ValueError(f"Unknown model: {model_name}")

# train
def train_epoch(model, train_loader, criterion, optimizer, device):
  model.train()
  running_loss = 0.0
  correct = 0
  total = 0

  pbar = tqdm(train_loader, desc="Training")

  for inputs, labels in pbar:
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item() * inputs.size(0)
    _, predicted = outputs.max(1)
    total += labels.size(0)
    correct += predicted.eq(labels).sum().item()

    # just a progress bar
    pbar.set_postfix({
      'loss': running_loss / total,
      'acc': 100. * correct / total
    })

  train_loss = running_loss / total
  train_acc = 100. * correct / total

  return train_loss, train_acc


# eval
def evaluate(model, test_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    test_loss = running_loss / total
    test_acc = 100. * correct / total

    return test_loss, test_acc


# train config
def train_centralized_model(
    model_name="lenet5",
    dataset_name="cifar100",
    batch_size=8192,
    epochs=100,
    lr=0.01,
    momentum=0.9,
    weight_decay=5e-4,
    lr_scheduler="lars",
    save_path="lenet5_model.pth"
):
    # load data
    train_loader, test_loader, num_classes = load_data(
        dataset_name=dataset_name,
        batch_size=batch_size
    )

    # model
    model = create_model(model_name, num_classes=num_classes)
    model = model.to(device)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    scaled_lr = lr * (batch_size / 128)    # linear‐scaling rule

    decay_params   = []
    no_decay_params = []
    for name, param in model.named_parameters():
        if not param.requires_grad:
            continue
        # any 1-D param (bias, BatchNorm weight, etc.) => no decay
        if param.ndim == 1:
            no_decay_params.append(param)
        else:
            decay_params.append(param)

    optimizer = LARS(
        [
            {'params': decay_params,    'weight_decay': weight_decay},
            {'params': no_decay_params, 'weight_decay': 0.0}
        ],
        lr=scaled_lr,
        momentum=momentum,
        # set the *global* default decay to 0, since we've handled it per-group:
        weight_decay=0.0,
        trust_coefficient=0.05
    )

    # lr
    if lr_scheduler == "lars":
        warmup_epochs = 5
        def lr_lambda(epoch):
            # linear warmup
            if epoch < warmup_epochs:
                return float(epoch + 1) / float(warmup_epochs)
            # then cosine decay
            return 0.5 * (
                1.0
                + math.cos(
                    math.pi * (epoch - warmup_epochs) / (epochs - warmup_epochs)
                )
            )

        scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)
    elif lr_scheduler == "step":
        scheduler = torch.optim.lr_scheduler.MultiStepLR(
            optimizer,
            milestones=[int(epochs * 0.5), int(epochs * 0.75)],
            gamma=0.1
        )
    else:
        raise ValueError(f"Unknown scheduler: {lr_scheduler}")

    # training history
    history = {
        'train_loss': [],
        'train_acc': [],
        'test_loss': [],
        'test_acc': [],
        'lr': []
    }

    # track best accuracy
    best_acc = 0.0

    # training loop
    for epoch in range(epochs):
        current_lr = optimizer.param_groups[0]['lr']
        print(f"\nEpoch [{epoch+1}/{epochs}] - Learning Rate: {current_lr:.6f}")

        # training for one epoch
        start_time = time.time()
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        train_time = time.time() - start_time

        # evaluate on test set
        test_loss, test_acc = evaluate(model, test_loader, criterion, device)

        # step learning rate scheduler
        scheduler.step()

        # stats
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%, "
              f"Time: {train_time:.2f}s")

        # save best model
        if test_acc > best_acc:
            best_acc = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'test_acc': test_acc,
            }, save_path)
            print(f"New best model saved with accuracy: {test_acc:.2f}%")

        # update history
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        history['lr'].append(current_lr)

    # load best model
    checkpoint = torch.load(save_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Best model loaded with accuracy: {checkpoint['test_acc']:.2f}%")

    return model, history

# visualization of model performance
def plot_training_history(history):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))

    # plot the loss
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['test_loss'], label='Test Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.set_title('Loss Curves')
    ax1.grid(True)

    # plot accuracy
    ax2.plot(history['train_acc'], label='Train Accuracy')
    ax2.plot(history['test_acc'], label='Test Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.set_title('Accuracy Curves')
    ax2.grid(True)

    # plot learning rate
    ax3.plot(history['lr'])
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Learning Rate')
    ax3.set_title('Learning Rate Schedule')
    ax3.set_yscale('log')
    ax3.grid(True)

    plt.tight_layout()
    plt.show()

# run benchmark
def run_centralized_benchmark():
    # LeNet5 config
    config = {
        'model_name': 'lenet5',
        'dataset_name': 'cifar100',
        'batch_size': 8192,
        'epochs': 100,
        'lr': 0.01,
        'momentum': 0.9,
        'weight_decay': 5e-4,
        'lr_scheduler': 'lars',
        'save_path': 'lenet5_model.pth'
    }

    print(f"Running LARS benchmark with {config['model_name']} on {config['dataset_name']}...")

    # Train model
    model, history = train_centralized_model(**config)

    # Plot results
    plot_training_history(history)

    # Save history
    with open('lenet5_history.pkl', 'wb') as f:
        pickle.dump(history, f)

    print("Lars benchmark completed!")

    return model, history

# run it
model, history = run_centralized_benchmark()
# Out:
# PyTorch version: 2.6.0+cu124
# Using device: cpu
# Running LARS benchmark with lenet5 on cifar100...
#
# Epoch [1/100] - Learning Rate: 0.128000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.6021, Train Acc: 1.48%, Test Loss: 4.5697, Test Acc: 1.65%, Time: 35.54s
# New best model saved with accuracy: 1.65%
#
# Epoch [2/100] - Learning Rate: 0.256000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.5451, Train Acc: 2.04%, Test Loss: 4.4120, Test Acc: 3.66%, Time: 34.50s
# New best model saved with accuracy: 3.66%
#
# Epoch [3/100] - Learning Rate: 0.384000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.3871, Train Acc: 3.05%, Test Loss: 4.2499, Test Acc: 4.32%, Time: 34.29s
# New best model saved with accuracy: 4.32%
#
# Epoch [4/100] - Learning Rate: 0.512000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.2354, Train Acc: 4.59%, Test Loss: 4.1593, Test Acc: 5.75%, Time: 33.57s
# New best model saved with accuracy: 5.75%
#
# Epoch [5/100] - Learning Rate: 0.640000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.1531, Train Acc: 5.82%, Test Loss: 4.1143, Test Acc: 5.61%, Time: 33.63s
#
# Epoch [6/100] - Learning Rate: 0.640000
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.1260, Train Acc: 6.14%, Test Loss: 4.0407, Test Acc: 6.48%, Time: 33.93s
# New best model saved with accuracy: 6.48%
#
# Epoch [7/100] - Learning Rate: 0.639825
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 4.0457, Train Acc: 7.06%, Test Loss: 3.9777, Test Acc: 7.75%, Time: 34.27s
# New best model saved with accuracy: 7.75%
#
# Epoch [8/100] - Learning Rate: 0.639300
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.9783, Train Acc: 7.83%, Test Loss: 3.9065, Test Acc: 9.25%, Time: 33.46s
# New best model saved with accuracy: 9.25%
#
# Epoch [9/100] - Learning Rate: 0.638427
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.9688, Train Acc: 8.12%, Test Loss: 3.8798, Test Acc: 10.53%, Time: 34.33s
# New best model saved with accuracy: 10.53%
#
# Epoch [10/100] - Learning Rate: 0.637205
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.9330, Train Acc: 9.10%, Test Loss: 3.8397, Test Acc: 10.49%, Time: 34.65s
#
# Epoch [11/100] - Learning Rate: 0.635636
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.8858, Train Acc: 9.88%, Test Loss: 3.7935, Test Acc: 10.65%, Time: 34.91s
# New best model saved with accuracy: 10.65%
#
# Epoch [12/100] - Learning Rate: 0.633722
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.8669, Train Acc: 9.95%, Test Loss: 3.7887, Test Acc: 11.53%, Time: 35.31s
# New best model saved with accuracy: 11.53%
#
# Epoch [13/100] - Learning Rate: 0.631465
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.7677, Train Acc: 11.44%, Test Loss: 3.7084, Test Acc: 12.06%, Time: 34.88s
# New best model saved with accuracy: 12.06%
#
# Epoch [14/100] - Learning Rate: 0.628867
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.7687, Train Acc: 11.39%, Test Loss: 3.7142, Test Acc: 12.15%, Time: 34.57s
# New best model saved with accuracy: 12.15%
#
# Epoch [15/100] - Learning Rate: 0.625931
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.7663, Train Acc: 11.42%, Test Loss: 3.6809, Test Acc: 13.00%, Time: 34.74s
# New best model saved with accuracy: 13.00%
#
# Epoch [16/100] - Learning Rate: 0.622662
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.6827, Train Acc: 12.83%, Test Loss: 3.6283, Test Acc: 13.64%, Time: 34.76s
# New best model saved with accuracy: 13.64%
#
# Epoch [17/100] - Learning Rate: 0.619061
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.6716, Train Acc: 12.97%, Test Loss: 3.6773, Test Acc: 12.87%, Time: 34.44s
#
# Epoch [18/100] - Learning Rate: 0.615133
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.6845, Train Acc: 12.63%, Test Loss: 3.6715, Test Acc: 13.33%, Time: 34.38s
#
# Epoch [19/100] - Learning Rate: 0.610882
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.6636, Train Acc: 13.31%, Test Loss: 3.5420, Test Acc: 15.07%, Time: 35.42s
# New best model saved with accuracy: 15.07%
#
# Epoch [20/100] - Learning Rate: 0.606313
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5919, Train Acc: 14.05%, Test Loss: 3.5287, Test Acc: 15.34%, Time: 34.77s
# New best model saved with accuracy: 15.34%
#
# Epoch [21/100] - Learning Rate: 0.601432
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5798, Train Acc: 14.60%, Test Loss: 3.5698, Test Acc: 14.42%, Time: 34.55s
#
# Epoch [22/100] - Learning Rate: 0.596242
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5617, Train Acc: 14.73%, Test Loss: 3.6219, Test Acc: 14.30%, Time: 33.95s
#
# Epoch [23/100] - Learning Rate: 0.590750
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5979, Train Acc: 14.50%, Test Loss: 3.5398, Test Acc: 15.26%, Time: 34.15s
#
# Epoch [24/100] - Learning Rate: 0.584963
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5417, Train Acc: 15.31%, Test Loss: 3.4561, Test Acc: 17.56%, Time: 34.12s
# New best model saved with accuracy: 17.56%
#
# Epoch [25/100] - Learning Rate: 0.578885
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4842, Train Acc: 16.29%, Test Loss: 3.4283, Test Acc: 17.36%, Time: 34.29s
#
# Epoch [26/100] - Learning Rate: 0.572525
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.5202, Train Acc: 15.51%, Test Loss: 3.4414, Test Acc: 17.20%, Time: 34.16s
#
# Epoch [27/100] - Learning Rate: 0.565888
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4573, Train Acc: 16.82%, Test Loss: 3.4307, Test Acc: 18.02%, Time: 34.17s
# New best model saved with accuracy: 18.02%
#
# Epoch [28/100] - Learning Rate: 0.558983
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4721, Train Acc: 16.87%, Test Loss: 3.3810, Test Acc: 18.41%, Time: 34.20s
# New best model saved with accuracy: 18.41%
#
# Epoch [29/100] - Learning Rate: 0.551816
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4364, Train Acc: 17.11%, Test Loss: 3.4052, Test Acc: 18.47%, Time: 33.82s
# New best model saved with accuracy: 18.47%
#
# Epoch [30/100] - Learning Rate: 0.544396
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4186, Train Acc: 17.41%, Test Loss: 3.3944, Test Acc: 18.43%, Time: 33.99s
#
# Epoch [31/100] - Learning Rate: 0.536730
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4071, Train Acc: 17.71%, Test Loss: 3.4003, Test Acc: 18.44%, Time: 34.04s
#
# Epoch [32/100] - Learning Rate: 0.528827
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.4016, Train Acc: 18.11%, Test Loss: 3.3198, Test Acc: 19.38%, Time: 33.96s
# New best model saved with accuracy: 19.38%
#
# Epoch [33/100] - Learning Rate: 0.520696
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.3282, Train Acc: 19.12%, Test Loss: 3.3175, Test Acc: 19.58%, Time: 34.06s
# New best model saved with accuracy: 19.58%
#
# Epoch [34/100] - Learning Rate: 0.512346
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.3401, Train Acc: 18.93%, Test Loss: 3.2940, Test Acc: 19.81%, Time: 34.23s
# New best model saved with accuracy: 19.81%
#
# Epoch [35/100] - Learning Rate: 0.503785
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.3520, Train Acc: 18.66%, Test Loss: 3.3978, Test Acc: 18.15%, Time: 33.92s
#
# Epoch [36/100] - Learning Rate: 0.495023
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.3551, Train Acc: 18.36%, Test Loss: 3.2913, Test Acc: 20.20%, Time: 34.07s
# New best model saved with accuracy: 20.20%
#
# Epoch [37/100] - Learning Rate: 0.486070
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.3153, Train Acc: 19.54%, Test Loss: 3.2616, Test Acc: 20.50%, Time: 34.15s
# New best model saved with accuracy: 20.50%
#
# Epoch [38/100] - Learning Rate: 0.476936
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.2799, Train Acc: 19.78%, Test Loss: 3.2748, Test Acc: 20.84%, Time: 33.94s
# New best model saved with accuracy: 20.84%
#
# Epoch [39/100] - Learning Rate: 0.467629
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.2835, Train Acc: 19.90%, Test Loss: 3.2341, Test Acc: 21.23%, Time: 34.22s
# New best model saved with accuracy: 21.23%
#
# Epoch [40/100] - Learning Rate: 0.458161
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.2377, Train Acc: 20.98%, Test Loss: 3.1609, Test Acc: 22.58%, Time: 34.30s
# New best model saved with accuracy: 22.58%
#
# Epoch [41/100] - Learning Rate: 0.448543
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.2624, Train Acc: 20.50%, Test Loss: 3.1854, Test Acc: 21.85%, Time: 33.80s
#
# Epoch [42/100] - Learning Rate: 0.438783
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.2395, Train Acc: 20.63%, Test Loss: 3.1467, Test Acc: 23.10%, Time: 33.93s
# New best model saved with accuracy: 23.10%
#
# Epoch [43/100] - Learning Rate: 0.428894
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1796, Train Acc: 21.88%, Test Loss: 3.1386, Test Acc: 23.37%, Time: 34.34s
# New best model saved with accuracy: 23.37%
#
# Epoch [44/100] - Learning Rate: 0.418885
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1684, Train Acc: 22.26%, Test Loss: 3.1881, Test Acc: 22.15%, Time: 34.10s
#
# Epoch [45/100] - Learning Rate: 0.408769
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1549, Train Acc: 22.39%, Test Loss: 3.1166, Test Acc: 23.83%, Time: 33.87s
# New best model saved with accuracy: 23.83%
#
# Epoch [46/100] - Learning Rate: 0.398555
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1840, Train Acc: 21.87%, Test Loss: 3.0940, Test Acc: 24.08%, Time: 33.83s
# New best model saved with accuracy: 24.08%
#
# Epoch [47/100] - Learning Rate: 0.388256
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1561, Train Acc: 22.49%, Test Loss: 3.0925, Test Acc: 24.33%, Time: 34.03s
# New best model saved with accuracy: 24.33%
#
# Epoch [48/100] - Learning Rate: 0.377882
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1356, Train Acc: 22.85%, Test Loss: 3.0910, Test Acc: 24.16%, Time: 33.57s
#
# Epoch [49/100] - Learning Rate: 0.367444
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1112, Train Acc: 23.17%, Test Loss: 3.1036, Test Acc: 23.79%, Time: 34.23s
#
# Epoch [50/100] - Learning Rate: 0.356955
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.1131, Train Acc: 23.12%, Test Loss: 3.0645, Test Acc: 24.46%, Time: 34.77s
# New best model saved with accuracy: 24.46%
#
# Epoch [51/100] - Learning Rate: 0.346425
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.0741, Train Acc: 23.92%, Test Loss: 3.0144, Test Acc: 25.81%, Time: 34.50s
# New best model saved with accuracy: 25.81%
#
# Epoch [52/100] - Learning Rate: 0.335867
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.0731, Train Acc: 23.92%, Test Loss: 3.1249, Test Acc: 23.38%, Time: 34.67s
#
# Epoch [53/100] - Learning Rate: 0.325291
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.0633, Train Acc: 24.10%, Test Loss: 2.9878, Test Acc: 25.98%, Time: 34.69s
# New best model saved with accuracy: 25.98%
#
# Epoch [54/100] - Learning Rate: 0.314709
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 3.0147, Train Acc: 25.13%, Test Loss: 2.9572, Test Acc: 27.23%, Time: 34.45s
# New best model saved with accuracy: 27.23%
#
# Epoch [55/100] - Learning Rate: 0.304133
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9794, Train Acc: 25.84%, Test Loss: 2.9498, Test Acc: 26.63%, Time: 34.38s
#
# Epoch [56/100] - Learning Rate: 0.293575
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9591, Train Acc: 26.27%, Test Loss: 2.9503, Test Acc: 27.01%, Time: 34.73s
#
# Epoch [57/100] - Learning Rate: 0.283045
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9682, Train Acc: 25.95%, Test Loss: 2.9421, Test Acc: 27.64%, Time: 34.92s
# New best model saved with accuracy: 27.64%
#
# Epoch [58/100] - Learning Rate: 0.272556
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9330, Train Acc: 26.53%, Test Loss: 2.8619, Test Acc: 28.85%, Time: 34.68s
# New best model saved with accuracy: 28.85%
#
# Epoch [59/100] - Learning Rate: 0.262118
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9298, Train Acc: 26.88%, Test Loss: 2.9315, Test Acc: 27.42%, Time: 34.66s
#
# Epoch [60/100] - Learning Rate: 0.251744
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9222, Train Acc: 26.74%, Test Loss: 2.8985, Test Acc: 28.01%, Time: 34.92s
#
# Epoch [61/100] - Learning Rate: 0.241445
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9277, Train Acc: 26.99%, Test Loss: 2.8789, Test Acc: 28.48%, Time: 35.05s
#
# Epoch [62/100] - Learning Rate: 0.231231
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.9013, Train Acc: 27.52%, Test Loss: 2.8635, Test Acc: 28.70%, Time: 35.27s
#
# Epoch [63/100] - Learning Rate: 0.221115
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8510, Train Acc: 28.35%, Test Loss: 2.8734, Test Acc: 28.43%, Time: 35.29s
#
# Epoch [64/100] - Learning Rate: 0.211106
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8504, Train Acc: 28.24%, Test Loss: 2.8393, Test Acc: 29.15%, Time: 34.75s
# New best model saved with accuracy: 29.15%
#
# Epoch [65/100] - Learning Rate: 0.201217
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8352, Train Acc: 28.74%, Test Loss: 2.8249, Test Acc: 29.45%, Time: 34.68s
# New best model saved with accuracy: 29.45%
#
# Epoch [66/100] - Learning Rate: 0.191457
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8238, Train Acc: 28.90%, Test Loss: 2.8195, Test Acc: 29.26%, Time: 34.80s
#
# Epoch [67/100] - Learning Rate: 0.181839
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8169, Train Acc: 28.85%, Test Loss: 2.8020, Test Acc: 29.86%, Time: 34.72s
# New best model saved with accuracy: 29.86%
#
# Epoch [68/100] - Learning Rate: 0.172371
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.8001, Train Acc: 29.29%, Test Loss: 2.7824, Test Acc: 29.79%, Time: 34.50s
#
# Epoch [69/100] - Learning Rate: 0.163064
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.7745, Train Acc: 29.75%, Test Loss: 2.8061, Test Acc: 29.45%, Time: 35.03s
#
# Epoch [70/100] - Learning Rate: 0.153930
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.7808, Train Acc: 29.83%, Test Loss: 2.7402, Test Acc: 31.02%, Time: 34.72s
# New best model saved with accuracy: 31.02%
#
# Epoch [71/100] - Learning Rate: 0.144977
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.7488, Train Acc: 30.33%, Test Loss: 2.7417, Test Acc: 30.99%, Time: 34.76s
#
# Epoch [72/100] - Learning Rate: 0.136215
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.7361, Train Acc: 30.86%, Test Loss: 2.7326, Test Acc: 31.31%, Time: 35.52s
# New best model saved with accuracy: 31.31%
#
# Epoch [73/100] - Learning Rate: 0.127654
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.7227, Train Acc: 31.09%, Test Loss: 2.7080, Test Acc: 31.98%, Time: 34.85s
# New best model saved with accuracy: 31.98%
#
# Epoch [74/100] - Learning Rate: 0.119304
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6964, Train Acc: 31.47%, Test Loss: 2.6866, Test Acc: 32.22%, Time: 34.82s
# New best model saved with accuracy: 32.22%
#
# Epoch [75/100] - Learning Rate: 0.111173
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6791, Train Acc: 31.92%, Test Loss: 2.6990, Test Acc: 32.18%, Time: 35.22s
#
# Epoch [76/100] - Learning Rate: 0.103270
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6839, Train Acc: 31.66%, Test Loss: 2.6873, Test Acc: 32.33%, Time: 35.07s
# New best model saved with accuracy: 32.33%
#
# Epoch [77/100] - Learning Rate: 0.095604
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6840, Train Acc: 32.01%, Test Loss: 2.6595, Test Acc: 32.76%, Time: 34.99s
# New best model saved with accuracy: 32.76%
#
# Epoch [78/100] - Learning Rate: 0.088184
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6627, Train Acc: 32.39%, Test Loss: 2.6447, Test Acc: 33.23%, Time: 35.01s
# New best model saved with accuracy: 33.23%
#
# Epoch [79/100] - Learning Rate: 0.081017
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6443, Train Acc: 32.70%, Test Loss: 2.6467, Test Acc: 33.01%, Time: 34.96s
#
# Epoch [80/100] - Learning Rate: 0.074112
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6357, Train Acc: 32.68%, Test Loss: 2.6533, Test Acc: 33.43%, Time: 34.92s
# New best model saved with accuracy: 33.43%
#
# Epoch [81/100] - Learning Rate: 0.067475
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6418, Train Acc: 32.55%, Test Loss: 2.6435, Test Acc: 33.78%, Time: 35.04s
# New best model saved with accuracy: 33.78%
#
# Epoch [82/100] - Learning Rate: 0.061115
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6295, Train Acc: 33.01%, Test Loss: 2.6401, Test Acc: 33.61%, Time: 34.86s
#
# Epoch [83/100] - Learning Rate: 0.055037
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6136, Train Acc: 33.17%, Test Loss: 2.6140, Test Acc: 34.23%, Time: 34.51s
# New best model saved with accuracy: 34.23%
#
# Epoch [84/100] - Learning Rate: 0.049250
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6035, Train Acc: 33.61%, Test Loss: 2.6191, Test Acc: 33.94%, Time: 34.74s
#
# Epoch [85/100] - Learning Rate: 0.043758
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5893, Train Acc: 33.97%, Test Loss: 2.6105, Test Acc: 33.55%, Time: 34.87s
#
# Epoch [86/100] - Learning Rate: 0.038568
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.6009, Train Acc: 33.69%, Test Loss: 2.5973, Test Acc: 34.46%, Time: 34.93s
# New best model saved with accuracy: 34.46%
#
# Epoch [87/100] - Learning Rate: 0.033687
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5932, Train Acc: 33.80%, Test Loss: 2.5927, Test Acc: 34.20%, Time: 35.11s
#
# Epoch [88/100] - Learning Rate: 0.029118
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5817, Train Acc: 33.92%, Test Loss: 2.5964, Test Acc: 34.11%, Time: 36.00s
#
# Epoch [89/100] - Learning Rate: 0.024867
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5741, Train Acc: 34.00%, Test Loss: 2.5909, Test Acc: 34.66%, Time: 34.68s
# New best model saved with accuracy: 34.66%
#
# Epoch [90/100] - Learning Rate: 0.020939
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5731, Train Acc: 34.10%, Test Loss: 2.5826, Test Acc: 34.62%, Time: 34.65s
#
# Epoch [91/100] - Learning Rate: 0.017338
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5659, Train Acc: 34.22%, Test Loss: 2.5826, Test Acc: 34.57%, Time: 34.50s
#
# Epoch [92/100] - Learning Rate: 0.014069
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5619, Train Acc: 34.35%, Test Loss: 2.5695, Test Acc: 35.07%, Time: 35.04s
# New best model saved with accuracy: 35.07%
#
# Epoch [93/100] - Learning Rate: 0.011133
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5649, Train Acc: 34.39%, Test Loss: 2.5714, Test Acc: 34.80%, Time: 34.93s
#
# Epoch [94/100] - Learning Rate: 0.008535
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5545, Train Acc: 34.57%, Test Loss: 2.5672, Test Acc: 34.90%, Time: 34.97s
#
# Epoch [95/100] - Learning Rate: 0.006278
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5536, Train Acc: 34.50%, Test Loss: 2.5685, Test Acc: 34.90%, Time: 34.80s
#
# Epoch [96/100] - Learning Rate: 0.004364
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5556, Train Acc: 34.62%, Test Loss: 2.5667, Test Acc: 35.04%, Time: 34.49s
#
# Epoch [97/100] - Learning Rate: 0.002795
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5484, Train Acc: 34.82%, Test Loss: 2.5641, Test Acc: 35.01%, Time: 34.45s
#
# Epoch [98/100] - Learning Rate: 0.001573
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5509, Train Acc: 34.69%, Test Loss: 2.5647, Test Acc: 35.09%, Time: 34.61s
# New best model saved with accuracy: 35.09%
#
# Epoch [99/100] - Learning Rate: 0.000700
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5479, Train Acc: 34.50%, Test Loss: 2.5641, Test Acc: 35.05%, Time: 34.90s
#
# Epoch [100/100] - Learning Rate: 0.000175
# Training:   0%|          | 0/7 [00:00<?, ?it/s]
# Train Loss: 2.5474, Train Acc: 34.82%, Test Loss: 2.5642, Test Acc: 35.11%, Time: 35.74s
# New best model saved with accuracy: 35.11%
# Best model loaded with accuracy: 35.11%
# Lars benchmark completed!
