# %%
# colab test

import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.nn.functional as F
from torchvision.datasets import CIFAR10, CIFAR100
import torchvision.models as models
from torch.utils.data import DataLoader

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import time
import pickle
import numpy as np
import random

print("PyTorch version:", torch.__version__)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Seeding for reproducibility
seed = 2025
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

# transforms
train_transform = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

test_transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])


# load data

def load_data(dataset_name="cifar100", batch_size=128, num_workers=2):

    if dataset_name.lower() == "cifar10":
        train_dataset = CIFAR10(root='./data', train=True, download=True, transform=train_transform)
        test_dataset = CIFAR10(root='./data', train=False, download=True, transform=test_transform)
        num_classes = 10
    elif dataset_name.lower() == "cifar100":
        train_dataset = CIFAR100(root='./data', train=True, download=True, transform=train_transform)
        test_dataset = CIFAR100(root='./data', train=False, download=True, transform=test_transform)
        num_classes = 100
    else:
        raise ValueError(f"Unknown dataset: {dataset_name}")

    # data loaders
    train_loader = DataLoader(
        train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=True
    )

    test_loader = DataLoader(
        test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=True
    )

    return train_loader, test_loader, num_classes


# model - LeNet5 from the paper [11]
class LeNet5(nn.Module):
  def __init__(self, num_classes=10):
    super(LeNet5, self).__init__()
    # Input: 3x32x32 (CIFAR has 3 color channels)
    self.conv1 = nn.Conv2d(3, 6, kernel_size=5)  # Output: 6x28x28
    self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)  # Output: 6x14x14
    self.conv2 = nn.Conv2d(6, 16, kernel_size=5)  # Output: 16x10x10
    self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2)  # Output: 16x5x5

    # fc layers
    self.fc1 = nn.Linear(16 * 5 * 5, 120)
    self.fc2 = nn.Linear(120, 84)
    self.fc3 = nn.Linear(84, num_classes)

  def forward(self, x):
        x = self.pool1(F.relu(self.conv1(x)))
        x = self.pool2(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5) # flatten
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

def create_model(model_name, num_classes=10):
    if model_name.lower() == "lenet5":
        return LeNet5(num_classes=num_classes)
    else:
        raise ValueError(f"Unknown model: {model_name}")

# train
def train_epoch(model, train_loader, criterion, optimizer, device):
  model.train()
  running_loss = 0.0
  correct = 0
  total = 0

  pbar = tqdm(train_loader, desc="Training")

  for inputs, labels in pbar:
    inputs, labels = inputs.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = model(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    running_loss += loss.item() * inputs.size(0)
    _, predicted = outputs.max(1)
    total += labels.size(0)
    correct += predicted.eq(labels).sum().item()

    # just a progress bar
    pbar.set_postfix({
      'loss': running_loss / total,
      'acc': 100. * correct / total
    })

  train_loss = running_loss / total
  train_acc = 100. * correct / total

  return train_loss, train_acc


# eval
def evaluate(model, test_loader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)

            running_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    test_loss = running_loss / total
    test_acc = 100. * correct / total

    return test_loss, test_acc


# train config
def train_centralized_model(
    model_name="lenet5",
    dataset_name="cifar100",
    batch_size=128,
    epochs=150,
    lr=0.01,
    momentum=0.9,
    weight_decay=5e-4,
    lr_scheduler="cosine",
    save_path="lenet5_model.pth"
):
    # load data
    train_loader, test_loader, num_classes = load_data(
        dataset_name=dataset_name,
        batch_size=batch_size
    )

    # model
    model = create_model(model_name, num_classes=num_classes)
    model = model.to(device)

    # Define loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(
        model.parameters(),
        lr=lr,
        momentum=momentum,
        weight_decay=weight_decay
    )

    # lr
    if lr_scheduler == "step":
        scheduler = torch.optim.lr_scheduler.MultiStepLR(
            optimizer,
            milestones=[int(epochs * 0.5), int(epochs * 0.75)],
            gamma=0.1
        )
    elif lr_scheduler == "cosine":
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
            optimizer,
            T_max=epochs
        )
    else:
        raise ValueError(f"Unknown scheduler: {lr_scheduler}")

    # training history
    history = {
        'train_loss': [],
        'train_acc': [],
        'test_loss': [],
        'test_acc': [],
        'lr': []
    }

    # track best accuracy
    best_acc = 0.0

    # training loop
    for epoch in range(epochs):
        current_lr = optimizer.param_groups[0]['lr']
        print(f"\nEpoch [{epoch+1}/{epochs}] - Learning Rate: {current_lr:.6f}")

        # training for one epoch
        start_time = time.time()
        train_loss, train_acc = train_epoch(model, train_loader, criterion, optimizer, device)
        train_time = time.time() - start_time

        # evaluate on test set
        test_loss, test_acc = evaluate(model, test_loader, criterion, device)

        # step learning rate scheduler
        scheduler.step()

        # stats
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%, "
              f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%, "
              f"Time: {train_time:.2f}s")

        # save best model
        if test_acc > best_acc:
            best_acc = test_acc
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'test_acc': test_acc,
            }, save_path)
            print(f"New best model saved with accuracy: {test_acc:.2f}%")

        # update history
        history['train_loss'].append(train_loss)
        history['train_acc'].append(train_acc)
        history['test_loss'].append(test_loss)
        history['test_acc'].append(test_acc)
        history['lr'].append(current_lr)

    # load best model
    checkpoint = torch.load(save_path)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f"Best model loaded with accuracy: {checkpoint['test_acc']:.2f}%")

    return model, history

# visualization of model performance
def plot_training_history(history):
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 5))

    # plot the loss
    ax1.plot(history['train_loss'], label='Train Loss')
    ax1.plot(history['test_loss'], label='Test Loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Loss')
    ax1.legend()
    ax1.set_title('Loss Curves')
    ax1.grid(True)

    # plot accuracy
    ax2.plot(history['train_acc'], label='Train Accuracy')
    ax2.plot(history['test_acc'], label='Test Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy (%)')
    ax2.legend()
    ax2.set_title('Accuracy Curves')
    ax2.grid(True)

    # plot learning rate
    ax3.plot(history['lr'])
    ax3.set_xlabel('Epoch')
    ax3.set_ylabel('Learning Rate')
    ax3.set_title('Learning Rate Schedule')
    ax3.set_yscale('log')
    ax3.grid(True)

    plt.tight_layout()
    plt.show()

# run benchmark
def run_centralized_benchmark():
    # LeNet5 config
    config = {
        'model_name': 'lenet5',
        'dataset_name': 'cifar100',
        'batch_size': 128,
        'epochs': 150,
        'lr': 0.01,
        'momentum': 0.9,
        'weight_decay': 5e-4,
        'lr_scheduler': 'cosine',
        'save_path': 'lenet5_model.pth'
    }

    print(f"Running centralized benchmark with {config['model_name']} on {config['dataset_name']}...")

    # Train model
    model, history = train_centralized_model(**config)

    # Plot results
    plot_training_history(history)

    # Save history
    with open('lenet5_history.pkl', 'wb') as f:
        pickle.dump(history, f)

    print("Centralized benchmark completed!")

    return model, history

# run it
model, history = run_centralized_benchmark()
# Out:
# PyTorch version: 2.6.0+cu124
# Using device: cpu
# Running centralized benchmark with lenet5 on cifar100...
#
# Epoch [1/150] - Learning Rate: 0.010000
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 4.4543, Train Acc: 3.02%, Test Loss: 4.1245, Test Acc: 6.29%, Time: 39.10s
# New best model saved with accuracy: 6.29%
#
# Epoch [2/150] - Learning Rate: 0.009999
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.9931, Train Acc: 8.30%, Test Loss: 3.7818, Test Acc: 11.80%, Time: 38.13s
# New best model saved with accuracy: 11.80%
#
# Epoch [3/150] - Learning Rate: 0.009996
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.7538, Train Acc: 12.06%, Test Loss: 3.5954, Test Acc: 14.81%, Time: 36.31s
# New best model saved with accuracy: 14.81%
#
# Epoch [4/150] - Learning Rate: 0.009990
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.5648, Train Acc: 15.46%, Test Loss: 3.4159, Test Acc: 18.01%, Time: 35.36s
# New best model saved with accuracy: 18.01%
#
# Epoch [5/150] - Learning Rate: 0.009982
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.4293, Train Acc: 17.88%, Test Loss: 3.2787, Test Acc: 21.35%, Time: 34.11s
# New best model saved with accuracy: 21.35%
#
# Epoch [6/150] - Learning Rate: 0.009973
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.3421, Train Acc: 19.47%, Test Loss: 3.2490, Test Acc: 21.13%, Time: 33.84s
#
# Epoch [7/150] - Learning Rate: 0.009961
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.2629, Train Acc: 20.57%, Test Loss: 3.1235, Test Acc: 23.82%, Time: 33.86s
# New best model saved with accuracy: 23.82%
#
# Epoch [8/150] - Learning Rate: 0.009946
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.2010, Train Acc: 21.93%, Test Loss: 3.0965, Test Acc: 23.74%, Time: 32.76s
#
# Epoch [9/150] - Learning Rate: 0.009930
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.1243, Train Acc: 23.27%, Test Loss: 3.0379, Test Acc: 25.50%, Time: 34.09s
# New best model saved with accuracy: 25.50%
#
# Epoch [10/150] - Learning Rate: 0.009911
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.0795, Train Acc: 24.09%, Test Loss: 2.9683, Test Acc: 26.95%, Time: 35.03s
# New best model saved with accuracy: 26.95%
#
# Epoch [11/150] - Learning Rate: 0.009891
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 3.0335, Train Acc: 25.10%, Test Loss: 2.9280, Test Acc: 27.20%, Time: 33.57s
# New best model saved with accuracy: 27.20%
#
# Epoch [12/150] - Learning Rate: 0.009868
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss:
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.3169, Train Acc: 39.71%, Test Loss: 2.3638, Test Acc: 39.52%, Time: 35.82s
#
# Epoch [92/150] - Learning Rate: 0.003356
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.3120, Train Acc: 39.77%, Test Loss: 2.3605, Test Acc: 39.84%, Time: 35.57s
# New best model saved with accuracy: 39.84%
#
# Epoch [93/150] - Learning Rate: 0.003257
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2976, Train Acc: 40.14%, Test Loss: 2.4191, Test Acc: 38.86%, Time: 36.50s
#
# Epoch [94/150] - Learning Rate: 0.003159
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.3070, Train Acc: 39.99%, Test Loss: 2.3626, Test Acc: 39.78%, Time: 37.26s
#
# Epoch [95/150] - Learning Rate: 0.003062
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2888, Train Acc: 40.12%, Test Loss: 2.3686, Test Acc: 39.20%, Time: 37.17s
#
# Epoch [96/150] - Learning Rate: 0.002966
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2932, Train Acc: 39.95%, Test Loss: 2.3451, Test Acc: 40.21%, Time: 35.78s
# New best model saved with accuracy: 40.21%
#
# Epoch [97/150] - Learning Rate: 0.002871
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2775, Train Acc: 40.42%, Test Loss: 2.3367, Test Acc: 40.38%, Time: 36.23s
# New best model saved with accuracy: 40.38%
#
# Epoch [98/150] - Learning Rate: 0.002777
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2775, Train Acc: 40.52%, Test Loss: 2.3212, Test Acc: 40.70%, Time: 35.48s
# New best model saved with accuracy: 40.70%
#
# Epoch [99/150] - Learning Rate: 0.002684
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2722, Train Acc: 40.82%, Test Loss: 2.3305, Test Acc: 40.95%, Time: 37.30s
# New best model saved with accuracy: 40.95%
#
# Epoch [100/150] - Learning Rate: 0.002591
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2662, Train Acc: 40.67%, Test Loss: 2.3622, Test Acc: 39.42%, Time: 37.22s
#
# Epoch [101/150] - Learning Rate: 0.002500
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2610, Train Acc: 40.83%, Test Loss: 2.3559, Test Acc: 39.68%, Time: 37.10s
#
# Epoch [102/150] - Learning Rate: 0.002410
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2630, Train Acc: 40.83%, Test Loss: 2.3253, Test Acc: 40.43%, Time: 35.41s
#
# Epoch [103/150] - Learning Rate: 0.002321
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2524, Train Acc: 40.72%, Test Loss: 2.3459, Test Acc: 40.52%, Time: 35.25s
#
# Epoch [104/150] - Learning Rate: 0.002233
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2335, Train Acc: 41.39%, Test Loss: 2.3178, Test Acc: 41.10%, Time: 35.73s
# New best model saved with accuracy: 41.10%
#
# Epoch [105/150] - Learning Rate: 0.002146
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2343, Train Acc: 41.39%, Test Loss: 2.3388, Test Acc: 40.37%, Time: 36.87s
#
# Epoch [106/150] - Learning Rate: 0.002061
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2325, Train Acc: 41.58%, Test Loss: 2.3358, Test Acc: 40.56%, Time: 38.39s
#
# Epoch [107/150] - Learning Rate: 0.001977
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2244, Train Acc: 41.51%, Test Loss: 2.3168, Test Acc: 40.54%, Time: 36.42s
#
# Epoch [108/150] - Learning Rate: 0.001894
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2213, Train Acc: 41.69%, Test Loss: 2.3174, Test Acc: 40.59%, Time: 35.31s
#
# Epoch [109/150] - Learning Rate: 0.001813
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2232, Train Acc: 41.73%, Test Loss: 2.2896, Test Acc: 41.04%, Time: 35.58s
#
# Epoch [110/150] - Learning Rate: 0.001733
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.2088, Train Acc: 42.02%, Test Loss: 2.2804, Test Acc: 41.06%, Time: 37.23s
#
# Epoch [111/150] - Learning Rate: 0.001654
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1980, Train Acc: 42.51%, Test Loss: 2.3196, Test Acc: 40.62%, Time: 37.59s
#
# Epoch [112/150] - Learning Rate: 0.001577
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1961, Train Acc: 42.32%, Test Loss: 2.2986, Test Acc: 41.33%, Time: 35.76s
# New best model saved with accuracy: 41.33%
#
# Epoch [113/150] - Learning Rate: 0.001502
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1966, Train Acc: 42.30%, Test Loss: 2.2891, Test Acc: 41.41%, Time: 35.00s
# New best model saved with accuracy: 41.41%
#
# Epoch [114/150] - Learning Rate: 0.001428
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1866, Train Acc: 42.35%, Test Loss: 2.2844, Test Acc: 41.37%, Time: 36.54s
#
# Epoch [115/150] - Learning Rate: 0.001355
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1851, Train Acc: 42.55%, Test Loss: 2.2976, Test Acc: 40.99%, Time: 39.12s
#
# Epoch [116/150] - Learning Rate: 0.001284
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1784, Train Acc: 42.61%, Test Loss: 2.2780, Test Acc: 41.75%, Time: 38.19s
# New best model saved with accuracy: 41.75%
#
# Epoch [117/150] - Learning Rate: 0.001215
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1805, Train Acc: 42.59%, Test Loss: 2.2753, Test Acc: 41.74%, Time: 36.93s
#
# Epoch [118/150] - Learning Rate: 0.001147
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1691, Train Acc: 42.79%, Test Loss: 2.2777, Test Acc: 41.79%, Time: 38.43s
# New best model saved with accuracy: 41.79%
#
# Epoch [119/150] - Learning Rate: 0.001082
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1700, Train Acc: 42.84%, Test Loss: 2.2668, Test Acc: 42.02%, Time: 38.79s
# New best model saved with accuracy: 42.02%
#
# Epoch [120/150] - Learning Rate: 0.001017
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1651, Train Acc: 43.04%, Test Loss: 2.2653, Test Acc: 42.00%, Time: 38.20s
#
# Epoch [121/150] - Learning Rate: 0.000955
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1565, Train Acc: 43.51%, Test Loss: 2.2687, Test Acc: 41.78%, Time: 39.43s
#
# Epoch [122/150] - Learning Rate: 0.000894
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1501, Train Acc: 43.45%, Test Loss: 2.2612, Test Acc: 41.87%, Time: 35.35s
#
# Epoch [123/150] - Learning Rate: 0.000835
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1446, Train Acc: 43.58%, Test Loss: 2.2586, Test Acc: 41.90%, Time: 36.77s
#
# Epoch [124/150] - Learning Rate: 0.000778
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1425, Train Acc: 43.52%, Test Loss: 2.2682, Test Acc: 41.66%, Time: 36.06s
#
# Epoch [125/150] - Learning Rate: 0.000723
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1382, Train Acc: 43.62%, Test Loss: 2.2556, Test Acc: 41.84%, Time: 36.98s
#
# Epoch [126/150] - Learning Rate: 0.000670
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1367, Train Acc: 43.74%, Test Loss: 2.2535, Test Acc: 42.09%, Time: 37.63s
# New best model saved with accuracy: 42.09%
#
# Epoch [127/150] - Learning Rate: 0.000618
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1325, Train Acc: 43.98%, Test Loss: 2.2669, Test Acc: 42.01%, Time: 37.31s
#
# Epoch [128/150] - Learning Rate: 0.000569
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1330, Train Acc: 44.07%, Test Loss: 2.2568, Test Acc: 42.05%, Time: 42.56s
#
# Epoch [129/150] - Learning Rate: 0.000521
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1213, Train Acc: 43.95%, Test Loss: 2.2592, Test Acc: 42.31%, Time: 38.20s
# New best model saved with accuracy: 42.31%
#
# Epoch [130/150] - Learning Rate: 0.000476
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1238, Train Acc: 44.22%, Test Loss: 2.2408, Test Acc: 42.44%, Time: 38.51s
# New best model saved with accuracy: 42.44%
#
# Epoch [131/150] - Learning Rate: 0.000432
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1148, Train Acc: 44.36%, Test Loss: 2.2506, Test Acc: 42.20%, Time: 36.22s
#
# Epoch [132/150] - Learning Rate: 0.000391
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1130, Train Acc: 44.21%, Test Loss: 2.2470, Test Acc: 42.15%, Time: 37.61s
#
# Epoch [133/150] - Learning Rate: 0.000351
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1025, Train Acc: 44.40%, Test Loss: 2.2402, Test Acc: 42.06%, Time: 36.29s
#
# Epoch [134/150] - Learning Rate: 0.000314
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1127, Train Acc: 44.28%, Test Loss: 2.2426, Test Acc: 42.20%, Time: 37.08s
#
# Epoch [135/150] - Learning Rate: 0.000278
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1078, Train Acc: 44.24%, Test Loss: 2.2438, Test Acc: 42.19%, Time: 38.96s
#
# Epoch [136/150] - Learning Rate: 0.000245
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.1047, Train Acc: 44.38%, Test Loss: 2.2439, Test Acc: 42.28%, Time: 36.21s
#
# Epoch [137/150] - Learning Rate: 0.000213
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0979, Train Acc: 44.61%, Test Loss: 2.2405, Test Acc: 42.52%, Time: 37.33s
# New best model saved with accuracy: 42.52%
#
# Epoch [138/150] - Learning Rate: 0.000184
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0951, Train Acc: 44.80%, Test Loss: 2.2441, Test Acc: 42.41%, Time: 38.52s
#
# Epoch [139/150] - Learning Rate: 0.000157
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0932, Train Acc: 44.90%, Test Loss: 2.2383, Test Acc: 42.62%, Time: 38.28s
# New best model saved with accuracy: 42.62%
#
# Epoch [140/150] - Learning Rate: 0.000132
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0899, Train Acc: 44.80%, Test Loss: 2.2388, Test Acc: 42.39%, Time: 40.28s
#
# Epoch [141/150] - Learning Rate: 0.000109
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0890, Train Acc: 45.05%, Test Loss: 2.2340, Test Acc: 42.56%, Time: 38.18s
#
# Epoch [142/150] - Learning Rate: 0.000089
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0962, Train Acc: 44.53%, Test Loss: 2.2355, Test Acc: 42.62%, Time: 37.29s
#
# Epoch [143/150] - Learning Rate: 0.000070
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0910, Train Acc: 44.77%, Test Loss: 2.2356, Test Acc: 42.56%, Time: 36.93s
#
# Epoch [144/150] - Learning Rate: 0.000054
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0933, Train Acc: 44.52%, Test Loss: 2.2361, Test Acc: 42.56%, Time: 36.63s
#
# Epoch [145/150] - Learning Rate: 0.000039
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0853, Train Acc: 44.87%, Test Loss: 2.2342, Test Acc: 42.68%, Time: 37.88s
# New best model saved with accuracy: 42.68%
#
# Epoch [146/150] - Learning Rate: 0.000027
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0912, Train Acc: 44.67%, Test Loss: 2.2361, Test Acc: 42.60%, Time: 38.90s
#
# Epoch [147/150] - Learning Rate: 0.000018
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0850, Train Acc: 44.87%, Test Loss: 2.2346, Test Acc: 42.68%, Time: 38.01s
#
# Epoch [148/150] - Learning Rate: 0.000010
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0821, Train Acc: 45.00%, Test Loss: 2.2345, Test Acc: 42.60%, Time: 38.40s
#
# Epoch [149/150] - Learning Rate: 0.000004
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0837, Train Acc: 45.05%, Test Loss: 2.2344, Test Acc: 42.59%, Time: 39.81s
#
# Epoch [150/150] - Learning Rate: 0.000001
# Training:   0%|          | 0/391 [00:00<?, ?it/s]
# Train Loss: 2.0865, Train Acc: 45.01%, Test Loss: 2.2342, Test Acc: 42.62%, Time: 37.85s
# Best model loaded with accuracy: 42.68%
# Centralized benchmark completed!
